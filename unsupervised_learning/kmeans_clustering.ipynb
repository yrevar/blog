# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## K-means clustering naive implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython import display
from images2gif import writeGif
from PIL import Image
import io
import scipy.misc
# %matplotlib inline

# %%
# Convert pyplot to pil image
def read_pil_image_from_plt(plt):
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    return Image.open(buf)

# %%
# Some simple utility functions
def getCentroidDistances(X, centroids):
    '''
    Args: 
        X: n (samples) x d (feature dim)
        centroids: k (num centroids) x d (feature dim)

    Returns:
        centroid_distances: n x k
    '''
    
    # initialize parameters
    k = len(centroids)
    centroid_distances = np.zeros(X.shape[:2] + (k,))
    
    if X.ndim != 3:
        raise ValueError("X array dimension other than 3 is not supported")
    
    if centroids.shape[-1] != X.shape[-1]:
        raise ValueError("Centroid dimension doesn't match with the input")

    # compute distance to all centroids
    for ki in range(k):
        centroid_distances[...,ki] = np.linalg.norm(X - centroids[ki], axis=X.ndim-1, keepdims=False)
        
    return centroid_distances

def predictCluster(X, centroids):
    
    '''
    Args: 
        centroid_distances: n (samples) x k (centroid distances) 

    Returns:
        cluster assignments: n (samples) x 1 
    '''
    return np.argmin(getCentroidDistances(X, centroids), axis=X.ndim-1)

def updateCentroids(X, assignments):
    
    if X.ndim != 3:
        raise ValueError("X array dimension other than 3 is not supported")
    
    centroid_idxs = np.unique(assignments)
    D_, K_ = 1 if X.ndim == 2 else X.shape[2], len(centroid_idxs) # Change this for >3D X array, i.e. > mxnxd dim data
    centroids = np.zeros((K_, D_))

    for c_idx in centroid_idxs:
        
        # Update centroid with the mean of the assigned observations
        in_curr_centroid = assignments == c_idx
        centroids[c_idx] = np.sum(X[in_curr_centroid], axis=0)/float(len(X[in_curr_centroid]))
    return centroids

def replace_input_with_centroid_values(assignments, centroids):
    
    segmented_image = np.zeros(assignments.shape+(centroids.shape[1],))
    centroid_idxs = np.unique(assignments)
    
    for c_idx in centroid_idxs:
        segmented_image[assignments == c_idx] = centroids[c_idx]
    
    return segmented_image


def plotClusters(X, centroids, assignments=[], show_labels=False, title=""):
    
    X_names = ['point{0}'.format(i+1) for i in range(len(X))]
    cluster_names = ['cluster{0}'.format(i) for i in range(len(centroids))]

    cmap_cluster = plt.cm.rainbow
    if len(assignments) == 0:
        colors = [1]*len(X)
        cmap_ = plt.cm.gray
    else:
        colors = assignments
        cmap_ = cmap_cluster
        
    plt.scatter(X[:,0], X[:,1], c=colors, cmap=cmap_,
                                    alpha=0.8, s=[100,100], label='data points')
    plt.scatter(centroids[:,0], centroids[:,1], c=range(len(centroids)), cmap=cmap_cluster, 
                                    alpha=0.5, s=[300,300], label='clusters')
    plt.xlabel("feature 1")
    plt.ylabel("feature 2")
    plt.title(title)
    plt.rcParams.update({'font.size':16})
    plt.tight_layout()
    
    if show_labels:
        for label, x, y in zip(X_names, X[:, 0], X[:, 1]):
            plt.annotate(
                label, 
                xy = (x, y), xytext = (20, 20),
                textcoords = 'offset points', ha = 'right', va = 'bottom',
                bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.3),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

        for label, x, y in zip(cluster_names, centroids[:, 0], centroids[:, 1]):
            plt.annotate(
                label, 
                xy = (x, y), xytext = (20, -30),
                textcoords = 'offset points', ha = 'right', va = 'bottom',
                bbox = dict(boxstyle = 'round,pad=0.5', fc = 'red', alpha = 0.3),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %%
X_train = 50 * np.random.rand(40, 2)

# Variable to store class prediction
y_pred = -1 * np.ones((len(X_train)))
N, D = X_train.shape
X_feature_range = np.vstack((X_train.min(axis=0), X_train.max(axis=0))).T # D (feature dim) x 2 (min, max)

# %% [markdown]
# ### Step 1: Initialize cluster centers

# %%
K = 4
# Centroid initialization - fixed
# centroids = np.array(([[10,10], [20,20]]))

# Centroid initialization - uniformly at random 
centroids = X_feature_range[:,0] + np.random.rand(K, D)*(X_feature_range[:,1]-X_feature_range[:,0])

# Centroid initialization - smart initialization 
# TODO

# %%
plotClusters(X_train, centroids, title="initial state")

# %% [markdown]
# ### Step 2: Assign observations to closest cluster center

# %%
# Assign clusters based on least square distances
assignments = predictCluster(X_train[:,np.newaxis], centroids)

# Plot data with assignments
plotClusters(X_train, centroids, assignments, title="Step: Cluster Assignment")

# %% [markdown]
# ### Step 3: Update Centroids as means of assigned observations

# %%
# New centroids
centroids = updateCentroids(X_train[:,np.newaxis], assignments)

# Plot data with assignments
plotClusters(X_train, centroids, title="Step: Cluster Update")

# %% [markdown]
# ### Repeat Step 2 and Step 3 until convergence
#
# Stop when centroid updates are within some epsilon.

# %%
epsilon = 1e-2
converged = None
step= 0
# plt.figure(figsize=(7,5))
# plotClusters(X_train, centroids)

print "K-Means Start.."
while not converged:
    
    # Assign clusters based on least square distances
    assignments = predictCluster(X_train[:,np.newaxis], centroids)
    # print assignments
    plt.figure(figsize=(14,5))
    
    plt.subplot(1,2,1)
    # Plot data with assignments
    plotClusters(X_train, centroids, assignments, title="Step {}: Cluster Assignment".format(2*step+1))

    # New centroids
    centroids_new = updateCentroids(X_train[:,np.newaxis], assignments)
    
    # Check for convergence
    if np.linalg.norm(centroids-centroids_new) < epsilon:
        converged = True
    
    centroids = centroids_new
    
    if not converged:
        plt.subplot(1,2,2)
        # Plot data with new assignments
        plotClusters(X_train, centroids, title="Step {}: Cluster Update".format(2*(step+1)))
    else:
        plt.title("Step {}: k-means converged".format(2*step+1))
    
    step += 1

print "K-Means Finished.."
# Out:
# K-Means Start..
# K-Means Finished..

# %% [markdown]
# ## Image segmentation using K-means
#
# There are far better techniques for doing image segmentation than k-means. This is just for illustration purpose only.

# %%
# let's read our desired image from the disk
spock_img = scipy.misc.imread("./spock.jpg")
plt.imshow(spock_img)

# %%
# Centroid Initialization: centroids will be the RGB pixel intensities. 
k = 4 # number of centroids
_,_,D = spock_img.shape
centroids = np.random.random(k*D).reshape(k,D)
print ''.join(["Centroid {0}: {1}\n".format(i,cnt) for i,cnt in enumerate(centroids)])
# Out:
# Centroid 0: [ 0.05345402  0.31687924  0.35192483]
# Centroid 1: [ 0.3688053   0.72705687  0.4233845 ]
# Centroid 2: [ 0.26930937  0.78435903  0.58451428]
# Centroid 3: [ 0.39353896  0.78959971  0.82565407]

# %%
# Run K-means
gif_images = []
for i in range(20):
    
    ax = plt.gca()
    ax.set_axis_bgcolor('white')
    plt.title("Centroids {}".format(centroids))

    assignments = predictCluster(spock_img, centroids)
    centroids = updateCentroids(spock_img, assignments)
    
    plt.imshow(assignments)
    display.clear_output(wait=True)
    display.display(plt.gcf())
    gif_images.append(read_pil_image_from_plt(plt))
plt.clf()
writeGif("./kmeans{}_spock.gif".format(k), gif_images, duration=0.3, dither=0)

# %% [markdown]
# <img src="./kmeans4_spock.gif">

# %%
X_seg = replace_input_with_centroid_values(assignments, centroids)
plt.imshow(X_seg)

# %% [markdown]
# As expected, the result is not much impressive.

# %% [markdown]
# ### Some interesting exercises to try:
#
# - What happens when we increase or decrease the value of K?
# - What happens when we set K = N (i.e., no. of training samples)?
# - What is the optimum value of K? How do we decide that?
# - Does this algorithm always converge to a solution? Is it a local or global optimum?
# - How can we speed up the convergence time?
# - What's the running time of this algorithm?
# - What should be the convergence criteria?
# - It's sensitive to initial cluster assignments, what would be a good strategy for initialization?
# - Each data point is assigned to either one or the other cluster. Would it make sense to have a mixed membership? What are the problems that require mixed membership of the data points?
# - Can we do better?
